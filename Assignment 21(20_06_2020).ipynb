# %% [markdown]
# <a href="https://colab.research.google.com/github/dubba1212/AIML/blob/master/DAY_21(20_06_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv")
df
# Out:
#       name_of_city  state_code  ... male_graduates  female_graduates
# 0          Abohar            3  ...           8612              7675
# 1        Achalpur           27  ...           5269              3594
# 2        Adilabad           28  ...           6797              3768
# 3       Adityapur           20  ...          12189              7036
# 4           Adoni           28  ...           7871              4031
# ..             ...         ...  ...            ...               ...
# 488  Vizianagaram           28  ...          19173             11483
# 489      Warangal           28  ...          69507             40106
# 490        Wardha           27  ...          10645              8718
# 491   Yamunanagar            6  ...          14349             15454
# 492      Yavatmal           27  ...           7397              6114
#
# [493 rows x 22 columns]

# %% [markdown]
# ###1.Check the data types and summary statistics of the dataset

# %%
df.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %%
df.describe(include="all")
# Out:
#        name_of_city  state_code  ... male_graduates  female_graduates
# count           493  493.000000  ...   4.930000e+02      4.930000e+02
# unique          492         NaN  ...            NaN               NaN
# top     Aurangabad          NaN  ...            NaN               NaN
# freq              2         NaN  ...            NaN               NaN
# mean            NaN   18.643002  ...   3.771556e+04      2.848680e+04
# std             NaN    9.297168  ...   9.849574e+04      7.951556e+04
# min             NaN    1.000000  ...   1.703000e+03      8.290000e+02
# 25%             NaN    9.000000  ...   9.289000e+03      6.114000e+03
# 50%             NaN   19.000000  ...   1.404900e+04      9.558000e+03
# 75%             NaN   27.000000  ...   2.787200e+04      2.086600e+04
# max             NaN   35.000000  ...   1.210040e+06      1.011097e+06
#
# [11 rows x 22 columns]

# %% [markdown]
# ###2.Select random columns as Series and random columns as dataframe

# %%
df[df.columns.to_series().sample(2)]
# Out:
#      population_total  literates_female
# 0              145238             44972
# 1              112293             43086
# 2              117388             37660
# 3              173988             54515
# 4              166537             45089
# ..                ...               ...
# 488            227533             80306
# 489            620116            217136
# 490            105543             43339
# 491            216628             74255
# 492            116714             46561
#
# [493 rows x 2 columns]

# %%
df.iloc[0]
# Out:
# name_of_city                                    Abohar
# state_code                                            3
# state_name                                       PUNJAB
# dist_code                                             9
# population_total                                 145238
# population_male                                   76840
# population_female                                 68398
# 0-6_population_total                              15870
# 0-6_population_male                                8587
# 0-6_population_female                              7283
# literates_total                                  103319
# literates_male                                    58347
# literates_female                                  44972
# sex_ratio                                           890
# child_sex_ratio                                     848
# effective_literacy_rate_total                     79.86
# effective_literacy_rate_male                      85.49
# effective_literacy_rate_female                    73.59
# location                          30.1452928,74.1993043
# total_graduates                                   16287
# male_graduates                                     8612
# female_graduates                                   7675
# Name: 0, dtype: object

# %%
type(_)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ###3.Convert the data type of integer cols to float and float cols to integer

# %%
df.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %%
for i in df.columns:
  if(df[i].dtype=='int64'):
    df[i]=df[i].astype('float64')
  elif(df[i].dtype=='float64'):
    df[i]=df[i].astype('int64')

# %%
df.dtypes
# Out:
# name_of_city                       object
# state_code                        float64
# state_name                         object
# dist_code                         float64
# population_total                  float64
# population_male                   float64
# population_female                 float64
# 0-6_population_total              float64
# 0-6_population_male               float64
# 0-6_population_female             float64
# literates_total                   float64
# literates_male                    float64
# literates_female                  float64
# sex_ratio                         float64
# child_sex_ratio                   float64
# effective_literacy_rate_total       int64
# effective_literacy_rate_male        int64
# effective_literacy_rate_female      int64
# location                           object
# total_graduates                   float64
# male_graduates                    float64
# female_graduates                  float64
# dtype: object

# %% [markdown]
# ###4.Visualize the missing values through heatmap

# %%
sns.heatmap(df.isna())

# %% [markdown]
# ###5.Dropt the duplicate values if found any

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name_of_city, state_code, state_name, dist_code, population_total, population_male, population_female, 0-6_population_total, 0-6_population_male, 0-6_population_female, literates_total, literates_male, literates_female, sex_ratio, child_sex_ratio, effective_literacy_rate_total, effective_literacy_rate_male, effective_literacy_rate_female, location, total_graduates, male_graduates, female_graduates]
# Index: []

# %% [markdown]
# ###6.Get the row which has highest population

# %%
df.loc[[df['population_total'].argmax()]]
# Out:
#         name_of_city  state_code  ... male_graduates  female_graduates
# 185  Greater Mumbai         27.0  ...       964964.0          837407.0
#
# [1 rows x 22 columns]

# %% [markdown]
# ###7.Calculate the mean of the population total grouped by States and sort the population total in ascending order and plot a horizontal bar chart for that.

# %%
df1 = df.groupby('state_name')

# %%
df['population_total'].mean()
# Out:
# 448112.37322515214

# %%
new_df=df1['population_total'].mean().sort_values(ascending=True)
new_df
# Out:
# state_name
# ANDAMAN & NICOBAR ISLANDS    100608.000000
# NAGALAND                     123777.000000
# MEGHALAYA                    143007.000000
# HIMACHAL PRADESH             169758.000000
# UTTARAKHAND                  223399.500000
# BIHAR                        258250.615385
# MANIPUR                      264986.000000
# PUDUCHERRY                   270900.500000
# MIZORAM                      291822.000000
# WEST BENGAL                  296123.098361
# HARYANA                      297611.150000
# ORISSA                       300323.400000
# MADHYA PRADESH               344471.593750
# ASSAM                        347788.500000
# CHHATTISGARH                 348657.555556
# RAJASTHAN                    360104.000000
# PUNJAB                       363867.250000
# KERALA                       393710.428571
# TRIPURA                      399688.000000
# UTTAR PRADESH                401633.730159
# JHARKHAND                    427825.900000
# ANDHRA PRADESH               432657.500000
# TAMIL NADU                   433731.093750
# JAMMU & KASHMIR              601662.333333
# KARNATAKA                    607688.307692
# GUJARAT                      615001.689655
# MAHARASHTRA                  877258.976744
# NCT OF DELHI                 898799.800000
# CHANDIGARH                   960787.000000
# Name: population_total, dtype: float64

# %%
new_df.plot(kind='barh')

# %% [markdown]
# ###8.Create a dataframe of five cities which have lowest population

# %%
df=df.sort_values(by='population_total')

# %%
df3=df[0:0]
df3
# Out:
# Empty DataFrame
# Columns: [name_of_city, state_code, state_name, dist_code, population_total, population_male, population_female, 0-6_population_total, 0-6_population_male, 0-6_population_female, literates_total, literates_male, literates_female, sex_ratio, child_sex_ratio, effective_literacy_rate_total, effective_literacy_rate_male, effective_literacy_rate_female, location, total_graduates, male_graduates, female_graduates]
# Index: []

# %%
df3=df3.append(df.head(5))
df3
# Out:
#     name_of_city  state_code  ... male_graduates  female_graduates
# 332       Nagda         23.0  ...         5707.0            4137.0
# 53     Banswara          8.0  ...         7837.0            6015.0
# 211  Hinganghat         27.0  ...         6684.0            4572.0
# 136       Datia         23.0  ...         7960.0            4757.0
# 376  Port Blair         35.0  ...         6717.0            5703.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ###9.Create a dataframe of  five cities which have highest  population

# %%
df4=df.iloc[0:0]
df4=df4.append(df.tail(5))
df4
# Out:
#            name_of_city  state_code  ... male_graduates  female_graduates
# 7            Ahmadabad         24.0  ...       435267.0          334591.0
# 184  Greater Hyderabad         28.0  ...       685402.0          478747.0
# 72            Bengaluru        29.0  ...       908363.0          682800.0
# 141              Delhi          7.0  ...      1210040.0         1011097.0
# 185     Greater Mumbai         27.0  ...       964964.0          837407.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ###10.Concatenate the top five and bottom five cities based on the population

# %%
df3.append(df4)
# Out:
#            name_of_city  state_code  ... male_graduates  female_graduates
# 332              Nagda         23.0  ...         5707.0            4137.0
# 53            Banswara          8.0  ...         7837.0            6015.0
# 211         Hinganghat         27.0  ...         6684.0            4572.0
# 136              Datia         23.0  ...         7960.0            4757.0
# 376         Port Blair         35.0  ...         6717.0            5703.0
# 7            Ahmadabad         24.0  ...       435267.0          334591.0
# 184  Greater Hyderabad         28.0  ...       685402.0          478747.0
# 72            Bengaluru        29.0  ...       908363.0          682800.0
# 141              Delhi          7.0  ...      1210040.0         1011097.0
# 185     Greater Mumbai         27.0  ...       964964.0          837407.0
#
# [10 rows x 22 columns]
