# %% [markdown]
# <a href="https://colab.research.google.com/github/dubba1212/AIML/blob/master/Assignment_19(18_06_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Take any dataset of your choice from Kaggle or UCI and do the analysis on the data
# ###Load the dataset in a proper structure

# %%
df = pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ###Get the number of rows and columns from the dataset

# %%
print('rows:-',df.shape[0])
# Out:
# rows:- 891

# %%
print('columns:-',df.shape[1])
# Out:
# columns:- 12

# %% [markdown]
# ###Check how many categorical and numerical columns are there
# Categorical - object type
# Numerical - int,float
# Boolean - bool

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print("Numerical:",len(df.select_dtypes(exclude="object").columns))
# Out:
# Numerical: 7

# %%
print("objects:",len(df.select_dtypes(include="object").columns))
# Out:
# objects: 5

# %% [markdown]
# ###Get the basic descriptive information from the dataset

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %% [markdown]
# ###Get the frequency of the categories in all the columns of the dataset

# %%
count = df.groupby(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']).count()
count
# Out:
# Empty DataFrame
# Columns: []
# Index: [(2, 1, 1, Cumings, Mrs. John Bradley (Florence Briggs Thayer), female, 38.0, 1, 0, PC 17599, 71.2833, C85, C), (4, 1, 1, Futrelle, Mrs. Jacques Heath (Lily May Peel), female, 35.0, 1, 0, 113803, 53.1, C123, S), (7, 0, 1, McCarthy, Mr. Timothy J, male, 54.0, 0, 0, 17463, 51.8625, E46, S), (11, 1, 3, Sandstrom, Miss. Marguerite Rut, female, 4.0, 1, 1, PP 9549, 16.7, G6, S), (12, 1, 1, Bonnell, Miss. Elizabeth, female, 58.0, 0, 0, 113783, 26.55, C103, S), (22, 1, 2, Beesley, Mr. Lawrence, male, 34.0, 0, 0, 248698, 13.0, D56, S), (24, 1, 1, Sloper, Mr. William Thompson, male, 28.0, 0, 0, 113788, 35.5, A6, S), (28, 0, 1, Fortune, Mr. Charles Alexander, male, 19.0, 3, 2, 19950, 263.0, C23 C25 C27, S), (53, 1, 1, Harper, Mrs. Henry Sleeper (Myna Haxtun), female, 49.0, 1, 0, PC 17572, 76.7292, D33, C), (55, 0, 1, Ostby, Mr. Engelhart Cornelius, male, 65.0, 0, 1, 113509, 61.9792, B30, C), (63, 0, 1, Harris, Mr. Henry Birkhardt, male, 45.0, 1, 0, 36973, 83.475, C83, S), (67, 1, 2, Nye, Mrs. (Elizabeth Ramell), female, 29.0, 0, 0, C.A. 29395, 10.5, F33, S), (76, 0, 3, Moen, Mr. Sigurd Hansen, male, 25.0, 0, 0, 348123, 7.65, F G73, S), (89, 1, 1, Fortune, Miss. Mabel Helen, female, 23.0, 3, 2, 19950, 263.0, C23 C25 C27, S), (93, 0, 1, Chaffee, Mr. Herbert Fuller, male, 46.0, 1, 0, W.E.P. 5734, 61.175, E31, S), (97, 0, 1, Goldschmidt, Mr. George B, male, 71.0, 0, 0, PC 17754, 34.6542, A5, C), (98, 1, 1, Greenfield, Mr. William Bertram, male, 23.0, 0, 1, PC 17759, 63.3583, D10 D12, C), (103, 0, 1, White, Mr. Richard Frasar, male, 21.0, 0, 1, 35281, 77.2875, D26, S), (111, 0, 1, Porter, Mr. Walter Chamberlain, male, 47.0, 0, 0, 110465, 52.0, C110, S), (119, 0, 1, Baxter, Mr. Quigg Edmond
isnull()
# Out:
#      PassengerId  Survived  Pclass   Name  ...  Ticket   Fare  Cabin  Embarked
# 0          False     False   False  False  ...   False  False   True     False
# 1          False     False   False  False  ...   False  False  False     False
# 2          False     False   False  False  ...   False  False   True     False
# 3          False     False   False  False  ...   False  False  False     False
# 4          False     False   False  False  ...   False  False   True     False
# ..           ...       ...     ...    ...  ...     ...    ...    ...       ...
# 886        False     False   False  False  ...   False  False   True     False
# 887        False     False   False  False  ...   False  False  False     False
# 888        False     False   False  False  ...   False  False   True     False
# 889        False     False   False  False  ...   False  False  False     False
# 890        False     False   False  False  ...   False  False   True     False
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df.isna())

# %%
import missingno as msno
msno.matrix(df)

# %%
msno.bar(df)

# %% [markdown]
# ###Impute the missing values based on numerical and categorical

# %%
df_mean_imputed = df.fillna(df.mean())
df_mean_imputed
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df_median_imputed = df.fillna(df.median())
df_median_imputed
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ###Plot all the columns from the dataset; try to get some observations from the plot and write your inferences below the plots generated

# %%
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df['Age-Range']= pd.cut(df.Age,[10,20,30,40,60,80])
df[['Age-Range','Age']]
# Out:
#         Age-Range   Age
# 0    (20.0, 30.0]  22.0
# 1    (30.0, 40.0]  38.0
# 2    (20.0, 30.0]  26.0
# 3    (30.0, 40.0]  35.0
# 4    (30.0, 40.0]  35.0
# ..            ...   ...
# 886  (20.0, 30.0]  27.0
# 887  (10.0, 20.0]  19.0
# 888           NaN   NaN
# 889  (20.0, 30.0]  26.0
# 890  (30.0, 40.0]  32.0
#
# [891 rows x 2 columns]

# %%
sns.countplot(x='Age-Range',data=df)

# %% [markdown]
# from the above plot we can see that there have many survices in the age of 20-30 than any other age

# %%
df.plot()

# %% [markdown]
# ###Select any column as output  from the dataset and plot the output column with some of the input columns, which are suitable from your data columns

# %%
new_df = df.head(100)
new_df
# Out:
#     PassengerId  Survived  Pclass  ...    Cabin Embarked     Age-Range
# 0             1         0       3  ...      NaN        S  (20.0, 30.0]
# 1             2         1       1  ...      C85        C  (30.0, 40.0]
# 2             3         1       3  ...      NaN        S  (20.0, 30.0]
# 3             4         1       1  ...     C123        S  (30.0, 40.0]
# 4             5         0       3  ...      NaN        S  (30.0, 40.0]
# ..          ...       ...     ...  ...      ...      ...           ...
# 95           96         0       3  ...      NaN        S           NaN
# 96           97         0       1  ...       A5        C  (60.0, 80.0]
# 97           98         1       1  ...  D10 D12        C  (20.0, 30.0]
# 98           99         1       2  ...      NaN        S  (30.0, 40.0]
# 99          100         0       2  ...      NaN        S  (30.0, 40.0]
#
# [100 rows x 13 columns]

# %%
X=new_df.drop('Cabin',axis=1)
y = new_df.iloc[:,5]

# %%
sns.countplot('Age-Range',hue="Cabin",data=new_df)

# %% [markdown]
# ###Encode the categorical columns using different kinds of encoding techniques from pandas and scikit-learn

# %%
new_df = pd.concat([new_df,pd.get_dummies(df.Cabin,prefix='Cabin',drop_first=True)],axis=1)
new_df
# Out:
#      PassengerId  Survived  Pclass  ... Cabin_F4 Cabin_G6  Cabin_T
# 0            1.0       0.0     3.0  ...        0        0        0
# 1            2.0       1.0     1.0  ...        0        0        0
# 2            3.0       1.0     3.0  ...        0        0        0
# 3            4.0       1.0     1.0  ...        0        0        0
# 4            5.0       0.0     3.0  ...        0        0        0
# ..           ...       ...     ...  ...      ...      ...      ...
# 886          NaN       NaN     NaN  ...        0        0        0
# 887          NaN       NaN     NaN  ...        0        0        0
# 888          NaN       NaN     NaN  ...        0        0        0
# 889          NaN       NaN     NaN  ...        0        0        0
# 890          NaN       NaN     NaN  ...        0        0        0
#
# [891 rows x 159 columns]
