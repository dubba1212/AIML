# %% [markdown]
# <a href="https://colab.research.google.com/github/dubba1212/AIML/blob/master/Assignment_24(24_06_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_boston
boston = load_boston()
boston
# Out:
# {'DESCR': ".. _boston_dataset:\n\nBoston house prices dataset\n---------------------------\n\n**Data Set Characteristics:**  \n\n    :Number of Instances: 506 \n\n    :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.\n\n    :Attribute Information (in order):\n        - CRIM     per capita crime rate by town\n        - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.\n        - INDUS    proportion of non-retail business acres per town\n        - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)\n        - NOX      nitric oxides concentration (parts per 10 million)\n        - RM       average number of rooms per dwelling\n        - AGE      proportion of owner-occupied units built prior to 1940\n        - DIS      weighted distances to five Boston employment centres\n        - RAD      index of accessibility to radial highways\n        - TAX      full-value property-tax rate
# ...

# %%
df = pd.DataFrame(boston.data,columns=boston.feature_names)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO       B  LSTAT
# 0    0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.90   4.98
# 1    0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.90   9.14
# 2    0.02729   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  392.83   4.03
# 3    0.03237   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  394.63   2.94
# 4    0.06905   0.0   2.18   0.0  0.458  ...  3.0  222.0     18.7  396.90   5.33
# ..       ...   ...    ...   ...    ...  ...  ...    ...      ...     ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  391.99   9.67
# 502  0.04527   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   9.08
# 503  0.06076   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   5.64
# 504  0.10959   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  393.45   6.48
# 505  0.04741   0.0  11.93   0.0  0.573  ...  1.0  273.0     21.0  396.90   7.88
#
# ...

# %%
df['MEDV']=boston.target
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX  ...    TAX  PTRATIO       B  LSTAT  MEDV
# 0    0.00632  18.0   2.31   0.0  0.538  ...  296.0     15.3  396.90   4.98  24.0
# 1    0.02731   0.0   7.07   0.0  0.469  ...  242.0     17.8  396.90   9.14  21.6
# 2    0.02729   0.0   7.07   0.0  0.469  ...  242.0     17.8  392.83   4.03  34.7
# 3    0.03237   0.0   2.18   0.0  0.458  ...  222.0     18.7  394.63   2.94  33.4
# 4    0.06905   0.0   2.18   0.0  0.458  ...  222.0     18.7  396.90   5.33  36.2
# ..       ...   ...    ...   ...    ...  ...    ...      ...     ...    ...   ...
# 501  0.06263   0.0  11.93   0.0  0.573  ...  273.0     21.0  391.99   9.67  22.4
# 502  0.04527   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   9.08  20.6
# 503  0.06076   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   5.64  23.9
# 504  0.10959   0.0  11.93   0.0  0.573  ...  273.0     21.0  393.45   6.48  22.0
# 505  0.04741   0.0  11.93   0.0  0.573  ...  273.0     21.0  396.90   7.88  11.9
#
# ...

# %% [markdown]
# ##Consider LSTAT (% lower status of the population) as input and build a SLR Model to predict the MEDV
# ###Find the correlation by plotting a scatter plot between those two variables and write down the observations like how the variable are related to each other

# %%
X = df[['LSTAT']]
y = df[['MEDV']]

# %%
with plt.style.context("dark_background"):
    plt.plot(X,y,"go")
    plt.xlabel('LSTAT I/P')
    plt.ylabel('MEDV O/P')
    plt.title("Scatter Plot")

# %% [markdown]
# ans: By Looking at the scatter plot we can clearly observe the correlation between the input and the output variable is negative correlation.

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lm.predict(X)
y_pred
# Out:
# array([[29.8225951 ],
#        [25.87038979],
#        [30.72514198],
#        [31.76069578],
#        [29.49007782],
#        [29.60408375],
#        [22.74472741],
#        [16.36039575],
#        [ 6.11886372],
#        [18.30799693],
#        [15.1253316 ],
#        [21.94668596],
#        [19.62856553],
#        [26.70643322],
#        [24.80633451],
#        [26.50692285],
#        [28.30251613],
#        [20.61661686],
#        [23.44776393],
#        [23.83728417],
#        [14.58380346],
#        [21.41465832],
#        [16.76891698],
#        [15.66685973],
#        [19.06803641],
#        [18.86852605],
#        [20.48360995],
#        [18.13698805],
#        [22.39320915],
#        [23.17224962],
#        [13.08272548],
#        [22.16519731],
#        [ 8.22797329],
#        [17.12043524],
#        [15.22983702],
#        [25.35736314],
#        [23.71377775],
#        [26.22190805],
#        [24.92984093],
#        [30.44962767],
#        [32.67274316],
# ...

# %%
from sklearn.metrics import r2_score
print(r2_score(y,y_pred))
# Out:
# 0.5441462975864797

# %%
with sns.axes_style('dark'):
    sns.regplot(X,y)

# %% [markdown]
# ###input = PTRATIO and output = MEDV

# %%
X = df[['PTRATIO']]
y = df[['MEDV']]

# %%
with plt.style.context("dark_background"):
    plt.plot(X,y,"go")
    plt.xlabel('PTRATIO I/P')
    plt.ylabel('MEDV O/P')
    plt.title("Scatter Plot")

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lm.predict(X)
y_pred
# Out:
# array([[29.33984545],
#        [23.9469072 ],
#        [23.9469072 ],
#        [22.00544944],
#        [22.00544944],
#        [22.00544944],
#        [29.55556297],
#        [29.55556297],
#        [29.55556297],
#        [29.55556297],
#        [29.55556297],
#        [29.55556297],
#        [29.55556297],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [17.04394626],
#        [20.92686179],
#        [20.92686179],
#        [20.92686179],
#        [20.92686179],
#        [22.86831956],
#        [22.86831956],
# ...

# %%
from sklearn.metrics import r2_score
print(r2_score(y,y_pred))
# Out:
# 0.257847318009223

# %%
with sns.axes_style('dark'):
    sns.regplot(X,y)

# %% [markdown]
# ###input = AGE and output = MEDV

# %%
X = df[['AGE']]
y = df[['MEDV']]

# %%
with plt.style.context("dark_background"):
    plt.plot(X,y,"go")
    plt.xlabel('PTRATIO I/P')
    plt.ylabel('MEDV O/P')
    plt.title("Scatter Plot")

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = lm.predict(X)
y_pred
# Out:
# array([[22.94846834],
#        [21.26113906],
#        [23.4534355 ],
#        [25.33782513],
#        [24.30325827],
#        [23.74902603],
#        [22.77604053],
#        [19.14274025],
#        [18.66240564],
#        [20.39900001],
#        [19.36443315],
#        [20.76848817],
#        [26.17533163],
#        [23.36722159],
#        [20.57142782],
#        [24.01998401],
#        [27.37001003],
#        [20.91628344],
#        [26.47092217],
#        [22.41886864],
#        [18.89641481],
#        [19.99256303],
#        [19.68465623],
#        [18.66240564],
#        [19.38906569],
#        [20.42363255],
#        [19.85708404],
#        [20.04182812],
#        [19.35211688],
#        [20.2265722 ],
#        [19.38906569],
#        [18.66240564],
#        [20.87933462],
#        [19.27821925],
#        [19.04421007],
#        [22.57898017],
#        [23.41648668],
#        [25.86742483],
#        [27.25916358],
#        [28.29373044],
#        [29.03270677],
# ...

# %%
from sklearn.metrics import r2_score
print(r2_score(y,y_pred))
# Out:
# 0.14209474407780442

# %%
with sns.axes_style('dark'):
    sns.regplot(X,y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_test_pred = lm.predict(X_test)
y_test_pred
# Out:
# array([[29.57751561],
#        [18.38103943],
#        [19.40873531],
#        [18.921932  ],
#        [24.64187091],
#        [24.26324611],
#        [24.70948248],
#        [23.99279983],
#        [26.79191888],
#        [20.3552973 ],
#        [18.38103943],
#        [18.38103943],
#        [18.86784274],
#        [18.38103943],
#        [18.62444108],
#        [30.55112223],
#        [23.15441635],
#        [27.2922445 ],
#        [27.42746764],
#        [26.29159325],
#        [24.83118331],
#        [18.74614191],
#        [20.38234193],
#        [27.56269079],
#        [27.33281144],
#        [18.38103943],
#        [19.84144936],
#        [18.58387414],
#        [21.62639484],
#        [19.00306588],
#        [18.8272758 ],
#        [20.49052045],
#        [21.19368079],
#        [23.10032709],
#        [20.53108739],
#        [19.86849399],
#        [18.38103943],
#        [19.78736011],
#        [20.2606411 ],
#        [18.7326196 ],
#        [29.41524783],
# ...

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,y_test_pred))
# Out:
# 0.047778948864252935

# %% [markdown]
# ####The r2_score of inputs LSTAT, PTRATIO and AGE on target MEDV are 0.5441462975864799, 0.257847318009223, 0.14209474407780442 respectively.
#
# From this we can say that the LSTAT has more correlation than others and age has least
#
# So LSTAT has more effect on the data¶
