# %% [markdown]
# <a href="https://colab.research.google.com/github/dubba1212/AIML/blob/master/Assignment_12(09_06_2020).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/Match%20(1).csv")

df
# Out:
#      Match_SK  match_id  ... Win_Margin Country_id
# 0           0    335987  ...      140.0          1
# 1           1    335988  ...       33.0          1
# 2           2    335989  ...        9.0          1
# 3           3    335990  ...        5.0          1
# 4           4    335991  ...        5.0          1
# ..        ...       ...  ...        ...        ...
# 632       632   1082646  ...       10.0          1
# 633       633   1082647  ...       20.0          1
# 634       634   1082648  ...        7.0          1
# 635       635   1082649  ...        6.0          1
# 636       636   1082650  ...        1.0          1
#
# [637 rows x 17 columns]

# %% [markdown]
# **1** Print ManOfMach count of each player in Hyderabad stadium

# %%
g = df.groupby("City_Name")
g.get_group("Hyderabad")
# Out:
#      Match_SK  match_id  ... Win_Margin Country_id
# 6           6    335993  ...        9.0          1
# 8           8    335995  ...        3.0          1
# 17         17    336004  ...        7.0          1
# 20         20    336007  ...        5.0          1
# 32         32    336019  ...       23.0          1
# 42         42    336029  ...       25.0          1
# 54         54    336042  ...        7.0          1
# 176       176    501204  ...        8.0          1
# 185       185    501213  ...       33.0          1
# 189       189    501217  ...        8.0          1
# 200       200    501229  ...       37.0          1
# 215       215    501244  ...       20.0          1
# 219       219    501248  ...        4.0          1
# 226       226    501255  ...        6.0          1
# 271       271    548334  ...        9.0          1
# 299       299    548364  ...       25.0          1
# 313       313    548378  ...        5.0          1
# ...

# %%
g.get_group("Hyderabad")['ManOfMach'].value_counts()
# Out:
# DA Warner            6
# DW Steyn             3
# A Mishra             2
# V Sehwag             2
# YK Pathan            2
# GH Vihari            2
# SK Raina             2
# WP Saha              1
# I Sharma             1
# UT Yadav             1
# R Vinay Kumar        1
# AT Rayudu            1
# PA Patel             1
# SC Ganguly           1
# B Kumar              1
# SL Malinga           1
# Mandeep Singh        1
# PC Valthaty          1
# V Kohli              1
# Mustafizur Rahman    1
# MR Marsh             1
# DJG Sammy            1
# CH Morris            1
# DJ Bravo             1
# AB Dinda             1
# SE Marsh             1
# G Gambhir            1
# MJ McClenaghan       1
# SK Trivedi           1
# Name: ManOfMach, dtype: int64

# %% [markdown]
# Plot a pie chart for the country_name column

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df['Country_Name'].value_counts()
# Out:
# India           560
# South Africa     57
# U.A.E            20
# Name: Country_Name, dtype: int64

# %%
Name=["India","U.A.E","South Africa"]
values=['560','20','57']
plt.pie(values,labels=Name,autopct="%0.2f%%",radius=1.5,explode=[0,0.2,0.2],startangle=45,colors=['blue','red','green'])
plt.show()
